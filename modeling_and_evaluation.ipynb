# %%
## Load data

# %%
import geopandas as gpd
import numpy as np
import pickle

# Load handcrafted features
mesh = gpd.read_file("/path/to/your/data/data.gpkg")

# Label assignment
mesh["label"] = np.where(
    (mesh["vegetation"] <= 0.95)
    & (mesh["ghsl"] >= 0.5)
    & (mesh["osm"] <= 0.5)
    & (mesh["favelas"] > 0.9),
    1,
    np.where(
        (mesh["vegetation"] <= 0.95)
        & (mesh["ghsl"] >= 0.5)
        & (mesh["osm"] <= 0.5)
        & (mesh["favelas"] == 0),
        0,
        np.nan,
    ),
)

# Filter valid labeled samples
dataset = mesh[mesh["label"].notna()].copy()

# Load zones shapefile
zones = gpd.read_file("/path/to/your/data/zones.shp")

# Compute centroids and perform spatial join with zones
dataset["centroid"] = dataset.geometry.centroid
points_zones = gpd.sjoin(
    dataset.set_geometry("centroid"),
    zones[["fid", "geometry"]],
    how="left",
    predicate="within",
)
dataset["zone"] = points_zones["fid"]
dataset = dataset.drop(columns=["centroid"])
dataset = dataset[dataset["zone"].notna()]

# Load precomputed deep features
with open("/path/to/your/data/deep_features.pkl", "rb") as f:
    features, ids = pickle.load(f)

# Ensure ID type consistency
id_type = type(dataset["id"].iloc[0])
ids = [id_type(i) for i in ids]

# Map deep learning features to dataset entries
id_to_features = dict(zip(ids, features))
dataset["deep_features"] = dataset["id"].map(id_to_features)

# %%
## Cross-validation: single view with expert features

# %%
from sklearn.neural_network import MLPClassifier
from sklearn.preprocessing import StandardScaler
from sklearn.pipeline import make_pipeline

from sklearn.utils import resample
from sklearn.metrics import f1_score, precision_score, recall_score, cohen_kappa_score

zones = dataset['zone'].unique().tolist() 
zones.reverse()

f1_scores = [[] for _ in range(len(zones))]
precision_scores = [[] for _ in range(len(zones))]
recall_scores = [[] for _ in range(len(zones))]
kappa_scores = [[] for _ in range(len(zones))]

f_cols = ['slope', 'profile_co', 'nodes', 'roads', 'mean_conne', 'min_connex', 'max_connex', 'vegetation', 'entropy'] 

for _ in range(10):
    
    folds = []
    
    for z in zones:
        dataset_zone = dataset[dataset['zone'] == z]
        X, y = dataset_zone[f_cols].values, dataset_zone['label'].values
        
        class_0 = X[y == 0]
        class_1 = X[y == 1]
        
        if len(class_0) > len(class_1):
            class_0_downsampled = resample(class_0, replace=False, n_samples=len(class_1))
            X_balanced = np.vstack([class_0_downsampled, class_1])
            y_balanced = np.hstack([np.zeros(len(class_0_downsampled)), np.ones(len(class_1))])
        else:
            class_1_downsampled = resample(class_1, replace=False, n_samples=len(class_0))
            X_balanced = np.vstack([class_0, class_1_downsampled])
            y_balanced = np.hstack([np.zeros(len(class_0)), np.ones(len(class_1_downsampled))])
            
        p = np.random.permutation(len(y_balanced))
        
        X_balanced, y_balanced = X_balanced[p], y_balanced[p]
        
        folds.append([X_balanced, y_balanced])

    for i in range(len(folds)):
        X_test, y_test = folds[i][0], folds[i][1]
        
        X_train = np.vstack([fold[0] for j, fold in enumerate(folds) if j != i])
        y_train = np.hstack([fold[1] for j, fold in enumerate(folds) if j != i])
        
        clf = make_pipeline(
            StandardScaler(),
            MLPClassifier(
                hidden_layer_sizes=(100,),
                activation="relu",
                solver="adam",
                max_iter=500,
                random_state=42
            )
        )
        clf.fit(X_train, y_train)
        
        y_pred = clf.predict(X_test)

        precision_scores[i].append(precision_score(y_test, y_pred))
        recall_scores[i].append(recall_score(y_test, y_pred))
        f1_scores[i].append(f1_score(y_test, y_pred))
        kappa_scores[i].append(cohen_kappa_score(y_test, y_pred))

for i in range(len(zones)):
    print(f"Précision zone {i+1}: {np.mean(precision_scores[i]):.2f} +/- {np.std(precision_scores[i]):.2f}")
    print(f"Rappel zone {i+1}: {np.mean(recall_scores[i]):.2f} +/- {np.std(recall_scores[i]):.2f}")
    print(f"F1-score zone {i+1}: {np.mean(f1_scores[i]):.2f} +/- {np.std(f1_scores[i]):.2f}")
    print(f"Kappa zone {i+1}: {np.mean(kappa_scores[i]):.2f} +/- {np.std(kappa_scores[i]):.2f}\n")
    
print(f"Précision: {np.mean([np.mean(f) for f in precision_scores]):.2f} +/- {np.std([np.mean(f) for f in precision_scores]):.2f}")
print(f"Rappel: {np.mean([np.mean(f) for f in recall_scores]):.2f} +/- {np.std([np.mean(f) for f in recall_scores]):.2f}")
print(f"F1-score: {np.mean([np.mean(f) for f in f1_scores]):.2f} +/- {np.std([np.mean(f) for f in f1_scores]):.2f}")
print(f"Kappa: {np.mean([np.mean(f) for f in kappa_scores]):.2f} +/- {np.std([np.mean(f) for f in kappa_scores]):.2f}")

# %%
## Cross-validation: single-view with deep features

# %%
from sklearn.neural_network import MLPClassifier
from sklearn.preprocessing import StandardScaler
from sklearn.pipeline import make_pipeline

from sklearn.utils import resample
from sklearn.metrics import f1_score, precision_score, recall_score, cohen_kappa_score

zones = dataset['zone'].unique().tolist() 
zones.reverse()

f1_scores = [[] for _ in range(len(zones))]
precision_scores = [[] for _ in range(len(zones))]
recall_scores = [[] for _ in range(len(zones))]
kappa_scores = [[] for _ in range(len(zones))]

for _ in range(10):
    
    folds = []
    
    for z in zones:
        dataset_zone = dataset[dataset['zone'] == z]
        X, y = np.array(dataset_zone['deep_features'].tolist()), dataset_zone['label'].values
        
        class_0 = X[y == 0]
        class_1 = X[y == 1]
        
        if len(class_0) > len(class_1):
            class_0_downsampled = resample(class_0, replace=False, n_samples=len(class_1))
            X_balanced = np.vstack([class_0_downsampled, class_1])
            y_balanced = np.hstack([np.zeros(len(class_0_downsampled)), np.ones(len(class_1))])
        else:
            class_1_downsampled = resample(class_1, replace=False, n_samples=len(class_0))
            X_balanced = np.vstack([class_0, class_1_downsampled])
            y_balanced = np.hstack([np.zeros(len(class_0)), np.ones(len(class_1_downsampled))])
            
        p = np.random.permutation(len(y_balanced))
        
        X_balanced, y_balanced = X_balanced[p], y_balanced[p]
        
        folds.append([X_balanced, y_balanced])

    for i in range(len(folds)):
        X_test, y_test = folds[i][0], folds[i][1]
        
        X_train = np.vstack([fold[0] for j, fold in enumerate(folds) if j != i])
        y_train = np.hstack([fold[1] for j, fold in enumerate(folds) if j != i])
        
        clf = make_pipeline(
            StandardScaler(),
            MLPClassifier(
                hidden_layer_sizes=(100,),
                activation="relu",
                solver="adam",
                max_iter=500,
                random_state=42
            )
        )
        clf.fit(X_train, y_train)
        
        y_pred = clf.predict(X_test)

        precision_scores[i].append(precision_score(y_test, y_pred))
        recall_scores[i].append(recall_score(y_test, y_pred))
        f1_scores[i].append(f1_score(y_test, y_pred))
        kappa_scores[i].append(cohen_kappa_score(y_test, y_pred))

for i in range(len(zones)):
    print(f"Précision zone {i+1}: {np.mean(precision_scores[i]):.2f} +/- {np.std(precision_scores[i]):.2f}")
    print(f"Rappel zone {i+1}: {np.mean(recall_scores[i]):.2f} +/- {np.std(recall_scores[i]):.2f}")
    print(f"F1-score zone {i+1}: {np.mean(f1_scores[i]):.2f} +/- {np.std(f1_scores[i]):.2f}")
    print(f"Kappa zone {i+1}: {np.mean(kappa_scores[i]):.2f} +/- {np.std(kappa_scores[i]):.2f}\n")
    
print(f"Précision: {np.mean([np.mean(f) for f in precision_scores]):.2f} +/- {np.std([np.mean(f) for f in precision_scores]):.2f}")
print(f"Rappel: {np.mean([np.mean(f) for f in recall_scores]):.2f} +/- {np.std([np.mean(f) for f in recall_scores]):.2f}")
print(f"F1-score: {np.mean([np.mean(f) for f in f1_scores]):.2f} +/- {np.std([np.mean(f) for f in f1_scores]):.2f}")
print(f"Kappa: {np.mean([np.mean(f) for f in kappa_scores]):.2f} +/- {np.std([np.mean(f) for f in kappa_scores]):.2f}")

# %%
## Cross-validation: early fusion baseline

# %%
from sklearn.neural_network import MLPClassifier
from sklearn.preprocessing import StandardScaler
from sklearn.pipeline import make_pipeline

from sklearn.utils import resample
from sklearn.metrics import f1_score, precision_score, recall_score, cohen_kappa_score

zones = dataset['zone'].unique().tolist() 
zones.reverse()

f_cols = ['slope', 'profile_co', 'nodes', 'roads', 'mean_conne', 'min_connex', 'max_connex'] 

f1_scores = [[] for _ in range(len(zones))]
precision_scores = [[] for _ in range(len(zones))]
recall_scores = [[] for _ in range(len(zones))]
kappa_scores = [[] for _ in range(len(zones))]

for _ in range(10):
    
    folds = []
    
    for z in zones:
        dataset_zone = dataset[dataset['zone'] == z]
        X, y = np.hstack((dataset_zone[f_cols].values, np.array(dataset_zone['deep_features'].tolist()))), dataset_zone['label'].values
        
        class_0 = X[y == 0]
        class_1 = X[y == 1]
        
        if len(class_0) > len(class_1):
            class_0_downsampled = resample(class_0, replace=False, n_samples=len(class_1))
            X_balanced = np.vstack([class_0_downsampled, class_1])
            y_balanced = np.hstack([np.zeros(len(class_0_downsampled)), np.ones(len(class_1))])
        else:
            class_1_downsampled = resample(class_1, replace=False, n_samples=len(class_0))
            X_balanced = np.vstack([class_0, class_1_downsampled])
            y_balanced = np.hstack([np.zeros(len(class_0)), np.ones(len(class_1_downsampled))])
            
        p = np.random.permutation(len(y_balanced))
        
        X_balanced, y_balanced = X_balanced[p], y_balanced[p]
        
        folds.append([X_balanced, y_balanced])

    for i in range(len(folds)):
        X_test, y_test = folds[i][0], folds[i][1]
        
        X_train = np.vstack([fold[0] for j, fold in enumerate(folds) if j != i])
        y_train = np.hstack([fold[1] for j, fold in enumerate(folds) if j != i])
        
        clf = make_pipeline(
            StandardScaler(),
            MLPClassifier(
                hidden_layer_sizes=(100,),
                activation="relu",
                solver="adam",
                max_iter=500,
                random_state=42
            )
        )
        clf.fit(X_train, y_train)
        
        y_pred = clf.predict(X_test)

        precision_scores[i].append(precision_score(y_test, y_pred))
        recall_scores[i].append(recall_score(y_test, y_pred))
        f1_scores[i].append(f1_score(y_test, y_pred))
        kappa_scores[i].append(cohen_kappa_score(y_test, y_pred))

for i in range(len(zones)):
    print(f"Précision zone {i+1}: {np.mean(precision_scores[i]):.2f} +/- {np.std(precision_scores[i]):.2f}")
    print(f"Rappel zone {i+1}: {np.mean(recall_scores[i]):.2f} +/- {np.std(recall_scores[i]):.2f}")
    print(f"F1-score zone {i+1}: {np.mean(f1_scores[i]):.2f} +/- {np.std(f1_scores[i]):.2f}")
    print(f"Kappa zone {i+1}: {np.mean(kappa_scores[i]):.2f} +/- {np.std(kappa_scores[i]):.2f}\n")
    
print(f"Précision: {np.mean([np.mean(f) for f in precision_scores]):.2f} +/- {np.std([np.mean(f) for f in precision_scores]):.2f}")
print(f"Rappel: {np.mean([np.mean(f) for f in recall_scores]):.2f} +/- {np.std([np.mean(f) for f in recall_scores]):.2f}")
print(f"F1-score: {np.mean([np.mean(f) for f in f1_scores]):.2f} +/- {np.std([np.mean(f) for f in f1_scores]):.2f}")
print(f"Kappa: {np.mean([np.mean(f) for f in kappa_scores]):.2f} +/- {np.std([np.mean(f) for f in kappa_scores]):.2f}")

# %%
## Cross-validation: intermediate fusion baseline

# %%
import torch
import torch.nn as nn
from torch.utils.data import DataLoader, TensorDataset
from sklearn.preprocessing import StandardScaler

from sklearn.linear_model import LogisticRegression
from sklearn.utils import resample
from sklearn.metrics import (
    f1_score,
    precision_score,
    recall_score,
    cohen_kappa_score
)

zones = dataset['zone'].unique().tolist()
zones.reverse()

f_cols = [
    'slope', 'profile_co', 'nodes', 'roads',
    'mean_conne', 'min_connex', 'max_connex'
]

f1_scores = [[] for _ in range(len(zones))]
precision_scores = [[] for _ in range(len(zones))]
recall_scores = [[] for _ in range(len(zones))]
kappa_scores = [[] for _ in range(len(zones))]

class HybridMLP(nn.Module):
    """End-to-end hybrid MLP with two independent branches."""

    def __init__(self, h_dim, dl_dim):
        super().__init__()

        self.h_branch = nn.Sequential(
            nn.Linear(h_dim, 100),
            nn.ReLU()
        )

        self.dl_branch = nn.Sequential(
            nn.Linear(dl_dim, 100),
            nn.ReLU()
        )

        self.final_classifier = nn.Linear(200, 2)

    def forward(self, h_X, dl_X):
        h_repr = self.h_branch(h_X)
        dl_repr = self.dl_branch(dl_X)
        x = torch.cat([h_repr, dl_repr], dim=1)
        return self.final_classifier(x)

for _ in range(10):

    h_folds = []
    dl_folds = []

    for z in zones:
        dataset_zone = dataset[dataset['zone'] == z]
        handcrafted_X = dataset_zone[f_cols].values
        dl_X = np.array(dataset_zone['deep_features'].tolist())
        y = dataset_zone['label'].values

        random_state = np.random.randint(1, 42)

        class_0 = handcrafted_X[y == 0]
        class_1 = handcrafted_X[y == 1]

        if len(class_0) > len(class_1):
            class_0_downsampled = resample(
                class_0,
                replace=False,
                n_samples=len(class_1),
                random_state=random_state
            )
            X_balanced = np.vstack([class_0_downsampled, class_1])
            y_balanced = np.hstack([
                np.zeros(len(class_0_downsampled)),
                np.ones(len(class_1))
            ])
        else:
            class_1_downsampled = resample(
                class_1,
                replace=False,
                n_samples=len(class_0),
                random_state=random_state
            )
            X_balanced = np.vstack([class_0, class_1_downsampled])
            y_balanced = np.hstack([
                np.zeros(len(class_0)),
                np.ones(len(class_1_downsampled))
            ])

        p = np.random.permutation(len(y_balanced))
        X_balanced, y_balanced = X_balanced[p], y_balanced[p]

        h_folds.append([X_balanced, y_balanced])

        class_0 = dl_X[y == 0]
        class_1 = dl_X[y == 1]

        if len(class_0) > len(class_1):
            class_0_downsampled = resample(
                class_0,
                replace=False,
                n_samples=len(class_1),
                random_state=random_state
            )
            X_balanced = np.vstack([class_0_downsampled, class_1])
            y_balanced = np.hstack([
                np.zeros(len(class_0_downsampled)),
                np.ones(len(class_1))
            ])
        else:
            class_1_downsampled = resample(
                class_1,
                replace=False,
                n_samples=len(class_0),
                random_state=random_state
            )
            X_balanced = np.vstack([class_0, class_1_downsampled])
            y_balanced = np.hstack([
                np.zeros(len(class_0)),
                np.ones(len(class_1_downsampled))
            ])

        X_balanced, y_balanced = X_balanced[p], y_balanced[p]

        dl_folds.append([X_balanced, y_balanced])

    for i in range(len(h_folds)):
        h_X_test, y_test = h_folds[i][0], h_folds[i][1]
        dl_X_test = dl_folds[i][0]

        h_X_train = np.vstack([
            fold[0] for j, fold in enumerate(h_folds) if j != i
        ])
        y_train = np.hstack([
            fold[1] for j, fold in enumerate(h_folds) if j != i
        ])

        dl_X_train = np.vstack([
            fold[0] for j, fold in enumerate(dl_folds) if j != i
        ])

        h_scaler = StandardScaler()
        dl_scaler = StandardScaler()

        h_X_train_scaled = h_scaler.fit_transform(h_X_train)
        h_X_test_scaled = h_scaler.transform(h_X_test)

        dl_X_train_scaled = dl_scaler.fit_transform(dl_X_train)
        dl_X_test_scaled = dl_scaler.transform(dl_X_test)

        h_X_train_tensor = torch.tensor(h_X_train_scaled, dtype=torch.float32)
        dl_X_train_tensor = torch.tensor(dl_X_train_scaled, dtype=torch.float32)
        y_train_tensor = torch.tensor(y_train, dtype=torch.long)

        h_X_test_tensor = torch.tensor(h_X_test_scaled, dtype=torch.float32)
        dl_X_test_tensor = torch.tensor(dl_X_test_scaled, dtype=torch.float32)

        train_dataset = TensorDataset(
            h_X_train_tensor,
            dl_X_train_tensor,
            y_train_tensor
        )

        batch_size = min(200, len(train_dataset))

        train_loader = DataLoader(
            train_dataset,
            batch_size=batch_size,
            shuffle=True
        )

        model = HybridMLP(
            h_dim=h_X_train.shape[1],
            dl_dim=dl_X_train.shape[1]
        )

        optimizer = torch.optim.Adam(
            model.parameters(),
            lr=0.001,
            betas=(0.9, 0.999),
            eps=1e-8,
            weight_decay=0.0001
        )

        criterion = nn.CrossEntropyLoss()

        model.train()

        for epoch in range(500):
            for h_batch, dl_batch, y_batch in train_loader:
                optimizer.zero_grad()
                logits = model(h_batch, dl_batch)
                loss = criterion(logits, y_batch)
                loss.backward()
                optimizer.step()

        model.eval()

        with torch.no_grad():
            train_logits = model(h_X_train_tensor, dl_X_train_tensor)
            test_logits = model(h_X_test_tensor, dl_X_test_tensor)

            train_pred = torch.argmax(train_logits, dim=1).numpy()
            y_pred = torch.argmax(test_logits, dim=1).numpy()

            h_logits = model.h_branch(h_X_test_tensor)
            dl_logits = model.dl_branch(dl_X_test_tensor)

        precision_scores[i].append(precision_score(y_test, y_pred))
        recall_scores[i].append(recall_score(y_test, y_pred))
        f1_scores[i].append(f1_score(y_test, y_pred))
        kappa_scores[i].append(cohen_kappa_score(y_test, y_pred))

for i in range(len(zones)):
    print(f"Précision zone {i + 1}: "
          f"{np.mean(precision_scores[i]):.2f} +/- "
          f"{np.std(precision_scores[i]):.2f}")
    print(f"Rappel zone {i + 1}: "
          f"{np.mean(recall_scores[i]):.2f} +/- "
          f"{np.std(recall_scores[i]):.2f}")
    print(f"F1-score zone {i + 1}: "
          f"{np.mean(f1_scores[i]):.2f} +/- "
          f"{np.std(f1_scores[i]):.2f}")
    print(f"Kappa zone {i + 1}: "
          f"{np.mean(kappa_scores[i]):.2f} +/- "
          f"{np.std(kappa_scores[i]):.2f}\n")

print(f"Précision: {np.mean([np.mean(f) for f in precision_scores]):.2f} +/- "
      f"{np.std([np.mean(f) for f in precision_scores]):.2f}")
print(f"Rappel: {np.mean([np.mean(f) for f in recall_scores]):.2f} +/- "
      f"{np.std([np.mean(f) for f in recall_scores]):.2f}")
print(f"F1-score: {np.mean([np.mean(f) for f in f1_scores]):.2f} +/- "
      f"{np.std([np.mean(f) for f in f1_scores]):.2f}")
print(f"Kappa: {np.mean([np.mean(f) for f in kappa_scores]):.2f} +/- "
      f"{np.std([np.mean(f) for f in kappa_scores]):.2f}")

# %%
## Cross-validation: late fusion (MUSICA)

# %%
from sklearn.neural_network import MLPClassifier
from sklearn.preprocessing import StandardScaler
from sklearn.pipeline import make_pipeline

from sklearn.utils import resample
from sklearn.metrics import f1_score, precision_score, recall_score, cohen_kappa_score, confusion_matrix

zones = dataset['zone'].unique().tolist() 
zones.reverse()

f_cols = ['slope', 'profile_co', 'nodes', 'roads', 'mean_conne', 'min_connex', 'max_connex']  

f1_scores = [[] for _ in range(len(zones))]
precision_scores = [[] for _ in range(len(zones))]
recall_scores = [[] for _ in range(len(zones))]
kappa_scores = [[] for _ in range(len(zones))]

h_preds = [[] for _ in range(len(zones))]
dl_preds = [[] for _ in range(len(zones))]
labels = [[] for _ in range(len(zones))]

for _ in range(10):
    
    h_folds = []
    dl_folds = []
    
    for z in zones:
        dataset_zone = dataset[dataset['zone'] == z]
        handcrafted_X = dataset_zone[f_cols].values
        dl_X = np.array(dataset_zone['deep_features'].tolist())
        y = dataset_zone['label'].values

        random_state = np.random.randint(1, 42)

        # Balancing handcrafted_X
        class_0 = handcrafted_X[y == 0]
        class_1 = handcrafted_X[y == 1]

        if len(class_0) > len(class_1):
            class_0_downsampled = resample(class_0, replace=False, n_samples=len(class_1), random_state=random_state)
            X_balanced = np.vstack([class_0_downsampled, class_1])
            y_balanced = np.hstack([np.zeros(len(class_0_downsampled)), np.ones(len(class_1))])
        else:
            class_1_downsampled = resample(class_1, replace=False, n_samples=len(class_0), random_state=random_state)
            X_balanced = np.vstack([class_0, class_1_downsampled])
            y_balanced = np.hstack([np.zeros(len(class_0)), np.ones(len(class_1_downsampled))])

        
        p = np.random.permutation(len(y_balanced))
        X_balanced, y_balanced = X_balanced[p], y_balanced[p]
        
        h_folds.append([X_balanced, y_balanced])

        # Balancing dl_X
        class_0 = dl_X[y == 0]
        class_1 = dl_X[y == 1]
        
        if len(class_0) > len(class_1):
            class_0_downsampled = resample(class_0, replace=False, n_samples=len(class_1), random_state=random_state)
            X_balanced = np.vstack([class_0_downsampled, class_1])
            y_balanced = np.hstack([np.zeros(len(class_0_downsampled)), np.ones(len(class_1))])
        else:
            class_1_downsampled = resample(class_1, replace=False, n_samples=len(class_0), random_state=random_state)
            X_balanced = np.vstack([class_0, class_1_downsampled])
            y_balanced = np.hstack([np.zeros(len(class_0)), np.ones(len(class_1_downsampled))])
        
        X_balanced, y_balanced = X_balanced[p], y_balanced[p]
        
        dl_folds.append([X_balanced, y_balanced])

    for i in range(len(h_folds)):
        # handcrafted_X predictions
        X_test, y_test = h_folds[i][0], h_folds[i][1]
        
        X_train = np.vstack([fold[0] for j, fold in enumerate(h_folds) if j != i])
        y_train = np.hstack([fold[1] for j, fold in enumerate(h_folds) if j != i])
        
        clf = make_pipeline(
            StandardScaler(),
            MLPClassifier(
                hidden_layer_sizes=(100,),
                activation="relu",
                solver="adam",
                max_iter=500,
                random_state=42
            )
        )
        clf.fit(X_train, y_train)
        
        h_y_pred = clf.predict(X_test)
        h_y_probas = np.take(clf.predict_proba(np.array(X_test)), 0, axis=1)
        
        # dl_X predictions
        X_test, y_test = dl_folds[i][0], dl_folds[i][1]
        
        X_train = np.vstack([fold[0] for j, fold in enumerate(dl_folds) if j != i])
        y_train = np.hstack([fold[1] for j, fold in enumerate(dl_folds) if j != i])
        
        clf = make_pipeline(
            StandardScaler(),
            MLPClassifier(
                hidden_layer_sizes=(100,),
                activation="relu",
                solver="adam",
                max_iter=500,
                random_state=42
            )
        )
        clf.fit(X_train, y_train)
        
        dl_y_pred = clf.predict(X_test)
        dl_y_probas = np.take(clf.predict_proba(np.array(X_test)), 0, axis=1)

        labels[i].append(y_test)
        h_preds[i].append(h_y_pred.copy())
        dl_preds[i].append(dl_y_pred.copy())

        mean_proba = (h_y_probas + dl_y_probas) / 2
        y_pred = (mean_proba < 0.5).astype(int)

        precision_scores[i].append(precision_score(y_test, y_pred))
        recall_scores[i].append(recall_score(y_test, y_pred))
        f1_scores[i].append(f1_score(y_test, y_pred))
        kappa_scores[i].append(cohen_kappa_score(y_test, y_pred))

for i in range(len(zones)):
    print(f"Précision zone {i+1}: {np.mean(precision_scores[i]):.2f} +/- {np.std(precision_scores[i]):.2f}")
    print(f"Rappel zone {i+1}: {np.mean(recall_scores[i]):.2f} +/- {np.std(recall_scores[i]):.2f}")
    print(f"F1-score zone {i+1}: {np.mean(f1_scores[i]):.2f} +/- {np.std(f1_scores[i]):.2f}")
    print(f"Kappa zone {i+1}: {np.mean(kappa_scores[i]):.2f} +/- {np.std(kappa_scores[i]):.2f}\n")
    
print(f"Précision: {np.mean([np.mean(f) for f in precision_scores]):.2f} +/- {np.std([np.mean(f) for f in precision_scores]):.2f}")
print(f"Rappel: {np.mean([np.mean(f) for f in recall_scores]):.2f} +/- {np.std([np.mean(f) for f in recall_scores]):.2f}")
print(f"F1-score: {np.mean([np.mean(f) for f in f1_scores]):.2f} +/- {np.std([np.mean(f) for f in f1_scores]):.2f}")
print(f"Kappa: {np.mean([np.mean(f) for f in kappa_scores]):.2f} +/- {np.std([np.mean(f) for f in kappa_scores]):.2f}")
